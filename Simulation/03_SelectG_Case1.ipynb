# %%
# Include necessary packages
library(tidyverse)

# library(mvtnorm)
library(condMVNorm)
library(MomTrunc)
# library(truncnorm)
# library(tmvtnorm)
# library(TTmoment)


library(doParallel)
# library(parallel)



path=getwd()
source(paste0(substring(path, 
                        1, 
                        tail(unlist(gregexpr(pattern ='/',path)),n=1)),
              "MixCenMVReg_EM.R"))

source(paste0(substring(path, 
                        1, 
                        tail(unlist(gregexpr(pattern ='/',path)),n=1)),
              "Util_Func.R"))
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: mvtnorm
#
# Loading required package: foreach
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: iterators
#
# Loading required package: parallel

# %%
load('true_pars.RData')
load('data_cens_case1_r51n1000.RData')

# %%
Ran_trails=32
replicate=length(data_cens_case1)

start=Sys.time()

no_cores=detectCores(logical = TRUE)  
# returns the number of available hardware threads, 
# and if it is FALSE, returns the number of physical cores


SelectG_case1=list()
for(g in 1:6){
    Solutions=list()
    for(i in 1:replicate){
          
        cl=makeCluster(no_cores)  
        registerDoParallel(cl)  

        solutions=foreach(k=1:Ran_trails, .errorhandling="pass") %dopar% {
            library(condMVNorm)
            library(MomTrunc)
            MixCenMVReg_EM(Y=data_cens_case1[[i]]$Y,
                           X=data_cens_case1[[i]]$X,
                           C=data_cens_case1[[i]]$censorID, 
                           G=g,
                           Max.iter=1000, diff.tol=1e-3, print=FALSE, calc_cov=FALSE)
        }
        stopCluster(cl)
        end=Sys.time()
        message(paste0("G = ",g,", i = ",i,", Time spent: ",round(end-start,2),units(end-start)))
        Solutions[[i]]=solutions
    }
    Select_G[[g]]=Solutions
}
    
save(SelectG_case1,file='SelectG_case1.RData')
# save(model1.1,file = "model1.1.RData")
Sys.time()-start
# Out:
# G = 1, i = 1, Time spent: 7.22secs
#
# G = 1, i = 2, Time spent: 14.98secs
#
# G = 1, i = 3, Time spent: 22.94secs
#
# G = 1, i = 4, Time spent: 31.1secs
#
# G = 1, i = 5, Time spent: 39.38secs
#
# G = 2, i = 1, Time spent: 1.84mins
#
# G = 2, i = 2, Time spent: 3.11mins
#
# G = 2, i = 3, Time spent: 4.15mins
#
# G = 2, i = 4, Time spent: 5.24mins
#
# G = 2, i = 5, Time spent: 7.24mins
#
# G = 3, i = 1, Time spent: 9.57mins
#
# G = 3, i = 2, Time spent: 12.65mins
#
# G = 3, i = 3, Time spent: 15.22mins
#
# G = 3, i = 4, Time spent: 17.33mins
#
# G = 3, i = 5, Time spent: 21.67mins
#
# G = 4, i = 1, Time spent: 29.55mins
#
# G = 4, i = 2, Time spent: 39.93mins
#
# G = 4, i = 3, Time spent: 54.56mins
#
# G = 4, i = 4, Time spent: 1.1hours
#
# G = 4, i = 5, Time spent: 1.28hours
#
# G = 5, i = 1, Time spent: 1.66hours
#
# G = 5, i = 2, Time spent: 1.94hours
#
# G = 5, i = 3, Time spent: 2.42hours
#
# G = 5, i = 4, Time spent: 2.72hours
#
# G = 5, i = 5, Time spent: 2.92hours
#
# G = 6, i = 1, Time spent: 3.36hours
#
# G = 6, i = 2, Time spent: 3.85hours
#
# G = 6, i = 3, Time spent: 4.31hours
#
# G = 6, i = 4, Time spent: 4.68hours
#
# G = 6, i = 5, Time spent: 5.12hours
# Time difference of 5.11796 hours
