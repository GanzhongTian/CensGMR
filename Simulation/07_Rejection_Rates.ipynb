# %% [markdown]
# # n=1000

# %%
load("case1_cens_RR_r500n1000.RData")
load("true_pars.RData")

data=case1_cens_RR

truth=c(as.vector(true_pars$BETA[[1]]),as.vector(true_pars$BETA[[2]]),as.vector(true_pars$BETA[[3]]))

REP=500

Zscores=list()

for(i in 1:REP){
    beta_hat=c(as.vector(data[[i]]$Beta$beta1),as.vector(data[[i]]$Beta$beta2),as.vector(data[[i]]$Beta$beta3))
    diff=beta_hat-truth
    Zscores[[i]]=diff/diag(data[[i]]$Cov)^0.5
}

Zscores=do.call(rbind, Zscores)

Reject=(abs(Zscores)>1.96)*1

Reject_Rates=apply(Reject,2,mean)

Reject_Rates

mean(Reject_Rates)
# Out:
# Y1_X0_1 Y1_X1_1 Y2_X0_1 Y2_X1_1 Y1_X0_2 Y1_X1_2 Y2_X0_2 Y2_X1_2 Y1_X0_3 Y1_X1_3
#   0.046   0.072   0.066   0.064   0.070   0.042   0.048   0.044   0.036   0.054
# Y2_X0_3 Y2_X1_3
#   0.074   0.066
# [1] 0.05683333

# %%
load("case2_cens_RR_r500n1000.RData")
load("true_pars.RData")

data=case2_cens_RR

truth=c(as.vector(true_pars$BETA[[1]]),as.vector(true_pars$BETA[[2]]),as.vector(true_pars$BETA[[3]]))

REP=500

Zscores=list()

for(i in 1:REP){
    beta_hat=c(as.vector(data[[i]]$Beta$beta1),as.vector(data[[i]]$Beta$beta2),as.vector(data[[i]]$Beta$beta3))
    diff=beta_hat-truth
    Zscores[[i]]=diff/diag(data[[i]]$Cov)^0.5
}

Zscores=do.call(rbind, Zscores)

Reject=(abs(Zscores)>1.96)*1

Reject_Rates=apply(Reject,2,mean)

Reject_Rates

mean(Reject_Rates)
# Out:
# Y1_X0_1 Y1_X1_1 Y2_X0_1 Y2_X1_1 Y1_X0_2 Y1_X1_2 Y2_X0_2 Y2_X1_2 Y1_X0_3 Y1_X1_3
#   0.160   0.066   0.066   0.066   0.060   0.074   0.068   0.068   0.046   0.070
# Y2_X0_3 Y2_X1_3
#   0.094   0.070
# [1] 0.07566667

# %%
true_pars
# Out:
# $PIE
# [1] 0.1 0.7 0.2
#
# $BETA
# $BETA[[1]]
#      [,1] [,2]
# [1,]    2   20
# [2,]    0   -2
#
# $BETA[[2]]
#      [,1] [,2]
# [1,]    3   25
# [2,]    1   -3
#
# $BETA[[3]]
#      [,1] [,2]
# [1,]  3.5   30
# [2,]  2.0   -5
#
#
# $SIGMA
# $SIGMA[[1]]
#      [,1] [,2]
# [1,]  1.0  0.1
# [2,]  0.1  1.0
#
# $SIGMA[[2]]
#      [,1] [,2]
# [1,]  2.0  0.2
# [2,]  0.2  0.5
#
# $SIGMA[[3]]
#      [,1] [,2]
# [1,]  0.5  0.3
# [2,]  0.3  2.0

# %% [markdown]
# # n=5000

# %%
load("case1_cens_RR_r500n5000.RData")
load("true_pars.RData")

data=case1_cens_RR

truth=c(as.vector(true_pars$BETA[[1]]),as.vector(true_pars$BETA[[2]]),as.vector(true_pars$BETA[[3]]))

REP=500

Zscores=list()

for(i in 1:REP){
    beta_hat=c(as.vector(data[[i]]$Beta$beta1),as.vector(data[[i]]$Beta$beta2),as.vector(data[[i]]$Beta$beta3))
    diff=beta_hat-truth
    Zscores[[i]]=diff/diag(data[[i]]$Cov)^0.5
}

Zscores=do.call(rbind, Zscores)

Reject=(abs(Zscores)>1.96)*1

Reject_Rates=apply(Reject,2,mean)

Reject_Rates

mean(Reject_Rates)
# Out:
# Y1_X0_1 Y1_X1_1 Y2_X0_1 Y2_X1_1 Y1_X0_2 Y1_X1_2 Y2_X0_2 Y2_X1_2 Y1_X0_3 Y1_X1_3
#   0.040   0.054   0.054   0.030   0.042   0.056   0.042   0.050   0.044   0.054
# Y2_X0_3 Y2_X1_3
#   0.056   0.064
# [1] 0.04883333

# %%
load("case2_cens_RR_r500n5000.RData")
load("true_pars.RData")

data=case2_cens_RR

truth=c(as.vector(true_pars$BETA[[1]]),as.vector(true_pars$BETA[[2]]),as.vector(true_pars$BETA[[3]]))

REP=500

Zscores=list()

for(i in 1:REP){
    beta_hat=c(as.vector(data[[i]]$Beta$beta1),as.vector(data[[i]]$Beta$beta2),as.vector(data[[i]]$Beta$beta3))
    diff=beta_hat-truth
    Zscores[[i]]=diff/diag(data[[i]]$Cov)^0.5
}

Zscores=do.call(rbind, Zscores)

Reject=(abs(Zscores)>1.96)*1

Reject_Rates=apply(Reject,2,mean)

Reject_Rates

mean(Reject_Rates)
# Out:
# Y1_X0_1 Y1_X1_1 Y2_X0_1 Y2_X1_1 Y1_X0_2 Y1_X1_2 Y2_X0_2 Y2_X1_2 Y1_X0_3 Y1_X1_3
#   0.156   0.052   0.058   0.032   0.058   0.056   0.050   0.056   0.048   0.048
# Y2_X0_3 Y2_X1_3
#   0.050   0.062
# [1] 0.0605

# %%
load('data_cens_case2_r500n5000.RData')

# %%
load('data_true_r500n5000.RData')

# %%
sum(data_true[[1]]$Y[data_true[[1]]$Labels==1,][,1]<=2.5)
# Out:
# [1] 342

# %%
data_true[[1]]$Y[data_true[[1]]$Labels==1,]
# Out:
#       Y1          Y2
#  [1,]  0.7696916  21.48265
#  [2,]  2.2123449  13.48540
#  [3,]  1.0594480  17.44138
#  [4,]  2.0272905  20.21032
#  [5,]  1.6266072  20.06425
#  [6,]  2.0384058  18.12149
#  [7,]  2.5118265  19.69550
#  [8,]  0.6146304  19.60057
#  [9,]  2.1169096  21.39899
# [10,] -0.4062306  19.88263
# [11,]  2.6472871  23.25006
# [12,]  2.2725402  21.44989
# [13,]  2.1313285  17.31978
# [14,]  3.3620304  19.95849
# [15,]  2.1826894  22.56547
# [16,]  1.8214452  21.84543
# [17,]  0.9238201  18.24640
# [18,]  1.8711018  15.92463
# [19,]  2.6179249  17.73656
# [20,]  1.3248195  22.86890
# [21,]  1.7999923  20.77176
# [22,]  0.3438609  19.58392
# [23,]  2.1506546  21.65596
# [24,]  3.3611013  21.73316
# [25,]  0.3762464  20.87089
# [26,]  2.8357180  19.11537
# [27,]  2.2409234  18.33690
# [28,]  0.9280559  21.38163
# [29,]  0.6341355  15.22183
# [30,]  1.1251427  22.84403
# [31,] ⋮           ⋮
# [32,] -0.03446092 17.29652
# [33,]  1.02944949 17.00437
# [34,]  1.13116767 21.67489
# [35,]  2.73294854 21.81810
# [36,]  2.04536913 23.03054
# [37,]  1.36299335 20.75114
# [38,]  0.96309530 14.74790
# [39,]  2.42231638 18.45854
# [40,]  0.60129738 18.80443
# [41,]  2.73243196 22.01855
# [42,]  1.83359589 18.71405
# [43,]  3.31957141 19.55582
# [44,]  1.97495341 24.18790
# [45,]  1.52463646 15.71087
# [46,]  2.24045797 21.46118
# [47,]  0.81473568 20.33408
# [48,]  1.61231009 19.73085
# [49,]  0.89708113 18.97064
# [50,]  1.11113848 20.58054
# [51,]  3.61202374 21.98343
# [52,]  1.64470848 19.84801
# [53,]  2.36771513 21.83415
# [54,]  2.40470641 18.11847
# [55,]  3.29145732 19.26085
# [56,]  0.14869213 18.82774
# [57,]  3.44621248 18.62828
# [58,] -0.47036136 18.26026
# [59,]  0.74372917 21.26747
# [60,]  2.09949072 20.75072
# [61,]  3.44490736 17.55626
